# %%
import os

if "newMode2021" in os.getcwd():
    os.chdir("..")

# %%
import time, yaml
import logging.config

stream = open("log_config.yml", "r")
conf = yaml.safe_load(stream)
conf["logfile"] = "logs/newModeHyperParams_%s.log" % str(time.time())
logging.config.dictConfig(conf)

# %%
from newMode2021.setup import get_data_p1

u2_dataset = "u2_273_37026_events.pkl"

data = get_data_p1(u2_dataset)
# Out:
# C:\Users\Main\PycharmProjects\XFEL-ML\newMode2021\setup.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   inp_df[name] = column
# C:\Users\Main\PycharmProjects\XFEL-ML\newMode2021\setup.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   inp_df[name] = column
# ...

# %%
import keras_tuner as kt
import tensorflow as tf
from utility.estimators.neural_network import tunable_ann

tuner = kt.BayesianOptimization(
    tunable_ann,
    objective="val_mae",
    max_trials=100,
    project_name="newModeHyperParamLogs_%s" % str(time.time()),
    overwrite=True,
)

# %%
tuner.search(data[0], data[2], 1_000, epochs=2_000, validation_split=0.15, verbose=1)
# Out:
# Trial 100 Complete [00h 03m 52s]
# val_mae: 0.6036235690116882
#
# Best val_mae So Far: 0.6036235690116882
# Total elapsed time: 07h 10m 09s

# %%
print(tuner.get_best_hyperparameters()[0].values)
# Out:
# {'num_layers': 1, 'units_0': 20, 'activation': 'relu', 'regularization': 'l2', 'drop_out': 0.1, 'batch_norm': False, 'loss': 'mae', 'learning_rate': 0.003, 'units_1': 10, 'units_2': 20}
